# %% [markdown]
# # Semantic search with FAISS (PyTorch)

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu

# %%
from datasets import load_dataset

issues_dataset = load_dataset("gtxygyzb/github-issues", split="train")
issues_dataset
# Out:
# Downloading readme:   0%|          | 0.00/6.32k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/3.05M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request', 'is_pull_request'],
#     num_rows: 1000
# })

# %%
issues_dataset = issues_dataset.filter(
    lambda x: (x["is_pull_request"] == False and len(x["comments"]) > 0)
)
issues_dataset
# Out:
# Filter:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason', 'draft', 'pull_request', 'is_pull_request'],
#     num_rows: 454
# })

# %%
columns = issues_dataset.column_names
columns_to_keep = ["title", "body", "html_url", "comments"]
columns_to_remove = set(columns_to_keep).symmetric_difference(columns)
issues_dataset = issues_dataset.remove_columns(columns_to_remove)
issues_dataset
# Out:
# Dataset({
#     features: ['html_url', 'title', 'comments', 'body'],
#     num_rows: 454
# })

# %%
issues_dataset.set_format("pandas")
df = issues_dataset[:]

# %%
comments_df = df.explode("comments", ignore_index=True)
comments_df.head(4)
# Out:
#                                             html_url  \
# 0  https://github.com/huggingface/datasets/issues...
# 1  https://github.com/huggingface/datasets/issues...
# 2  https://github.com/huggingface/datasets/issues...
# 3  https://github.com/huggingface/datasets/issues...
#
#                                                title  \
# 0  Dataset.get_nearest_examples does not return a...
# 1  Dataset.get_nearest_examples does not return a...
# 2  FilesIterable skips all the files after a hidd...
# 3  AssertionError: daemonic processes are not all...
#
#                                             comments  \
# 0  Actually, my bad -- specifying\r\n```python\r\...
# 1  Actually, my bad -- specifying\r\n```python\r\...
# 2  Thanks for reporting. We've merged a PR with a...
# 3  We could add a "threads" parallel backend to `...
#
#                                                 body
# 0  ### Describe the bug\n\nHi team!\r\n\r\nI obse...
# 1  ### Describe the bug\n\nHi team!\r\n\r\nI obse...
# 2  ### Describe the bug\n\nWhen initializing `Fil...
# 3  ### Describe the bug\n\nWhen I load_dataset wi...

# %%
from datasets import Dataset

comments_dataset = Dataset.from_pandas(comments_df)
comments_dataset
# Out:
# Dataset({
#     features: ['html_url', 'title', 'comments', 'body'],
#     num_rows: 1662
# })

# %%
comments_dataset = comments_dataset.map(
    lambda x: {"comment_length": len(x["comments"].split())}
)
# Out:
# Map:   0%|          | 0/1662 [00:00<?, ? examples/s]

# %%
comments_dataset = comments_dataset.filter(lambda x: x["comment_length"] > 15)
comments_dataset
# Out:
# Filter:   0%|          | 0/1662 [00:00<?, ? examples/s]
# Dataset({
#     features: ['html_url', 'title', 'comments', 'body', 'comment_length'],
#     num_rows: 1234
# })

# %%
comments_dataset = comments_dataset.filter(lambda x: x["title"] and x["body"] is not None)
comments_dataset
# Out:
# Filter:   0%|          | 0/1234 [00:00<?, ? examples/s]
# Dataset({
#     features: ['html_url', 'title', 'comments', 'body', 'comment_length'],
#     num_rows: 1232
# })

# %%
def concatenate_text(examples):
    return {
        "text": examples["title"]
        + " \n "
        + examples["body"]
        + " \n "
        + examples["comments"]
    }


comments_dataset = comments_dataset.map(concatenate_text)
# Out:
# Map:   0%|          | 0/1232 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer, AutoModel

model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
import torch

device = torch.device("cuda")
model.to(device)
# Out:
# MPNetModel(
#   (embeddings): MPNetEmbeddings(
#     (word_embeddings): Embedding(30527, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): MPNetEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (relative_attention_bias): Embedding(32, 12)
#   )
#   (pooler): MPNetPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def cls_pooling(model_output):
  return model_output.last_hidden_state[:, 0]

# %%
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="pt"
    )
    encoded_input = {k: v.to(device) for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output)

# %%
embedding = get_embeddings(comments_dataset["text"][0])
embedding.shape
# Out:
# torch.Size([1, 512, 768])
# torch.Size([1, 768])

# %%
embeddings_dataset = comments_dataset.map(
    lambda x: {"embeddings": get_embeddings(x["text"]).detach().cpu().numpy()[0]}
)
# Out:
# Map:   0%|          | 0/1232 [00:00<?, ? examples/s]

# %%
embeddings_dataset.add_faiss_index(column="embeddings")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset({
#     features: ['html_url', 'title', 'comments', 'body', 'comment_length', 'text', 'embeddings'],
#     num_rows: 1232
# })

# %%
question = "How can I install transformer library?"
question_embedding = get_embeddings([question]).cpu().detach().numpy()
question_embedding.shape
# Out:
# (1, 768)

# %%
scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=5
)

# %%
import pandas as pd

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=False, inplace=True)

# %%
for _, row in samples_df.iterrows():
    print(f"COMMENT: {row.comments}")
    print(f"SCORE: {row.scores}")
    print(f"TITLE: {row.title}")
    print(f"URL: {row.html_url}")
    print("=" * 50)
    print()
# Out:
# COMMENT: cc @albertvillanova the author would like to add this dataset to the hub: https://github.com/microsoft/table-transformer/issues/68#issuecomment-1319114621. Could you help him out?
# SCORE: 45.6834602355957
# TITLE: Add PubTables-1M
# URL: https://github.com/huggingface/datasets/issues/5261
# ==================================================
#
# COMMENT: > Looks related to https://discuss.huggingface.co/t/indexerror-invalid-key-16-is-out-of-bounds-for-size-0/14298/4?u=lhoestq
#
# The problem has not been solved, I have tried this before, but the problem is the same
# SCORE: 43.770816802978516
# TITLE: IndexError Not Solving -> IndexError: Invalid key: ?? is out of bounds for size 0 or ??
# URL: https://github.com/huggingface/datasets/issues/5946
# ==================================================
#
# COMMENT: > >
# >
# > @syngokhan did u solve it? I am desperate
#
# refer to my earlier comment. you will find the solution.
# SCORE: 43.770816802978516
# TITLE: IndexError Not Solving -> IndexError: Invalid key: ?? is out of bounds for size 0 or ??
# URL: https://github.com/huggingface/datasets/issues/5946
# ==================================================
#
# COMMENT: data = data["train"].shuffle().map(generate_and_tokenize_prompt, batched = False) # change this line to -
#
# data["train"] = data["train"].shuffle().map(generate_and_tokenize_prompt, batched = False)
# After doing this change you code should run fine.
# SCORE: 43.770816802978516
# TITLE: IndexError Not Solving -> IndexError: Invalid key: ?? is out of bounds for size 0 or ??
# URL: https://github.com/huggingface/datasets/issues/5946
# ==================================================
#
# COMMENT: @MFatnassi, this issue and the corresponding fix only affect our Continuous Integration testing environment.
#
# Note that `datasets` does not depend on `spacy`.
# SCORE: 41.915374755859375
# TITLE: CI error: TypeError: dataclass_transform() got an unexpected keyword argument 'field_specifiers'
# URL: https://github.com/huggingface/datasets/issues/5394
# ==================================================
